# %%
import pandas as pd

novosProdutos_df = pd.read_csv(r'Tratamento de Dados e Multiplas Bases\Contoso - Cadastro Produtos.csv',sep=';',encoding='ISO-8859-1')
# .head() pega os primeiros itens do dataframe
#display(novosProdutos_df.head()) # display(novosProdutos_df[:5])

novosProdutos_df = novosProdutos_df.rename(columns={'ÿNome do Produto': 'Nome do Produto'})

#loc = permite pegar uma linha de acordo com o índice dela. dá erro se não achaar o índice
#transformar a coluna nome em indice para usar o loc
novosProdutos_df = novosProdutos_df.set_index('Nome do Produto')
#pegando o preco unitario com o loc
print(novosProdutos_df.loc['Contoso Optical Wheel OEM PS/2 Mouse E60 Grey','Preco Unitario'])

# iloc tem que passar o numero daa linha e o da coluna
#print(novosProdutos_df.iloc[2,6])


novosProdutos_df.loc['Contoso Optical Wheel OEM PS/2 Mouse E60 Grey','Preco Unitario'] = 23
novosProdutos_df.loc[novosProdutos_df['ID Produto'] == 873, 'Preco Unitario'] = 23


display(novosProdutos_df.head())
# Out:
# 13
#                                                                               Descricao do Produto  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Advanced 2.4 GHz cordless technology makes fre...
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey                       PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 White                      PS/2 mouse, 6 feet mouse cable
# Contoso Optical Wheel OEM PS/2 Mouse E60 Silver                     PS/2 mouse, 6 feet mouse cable
#
#                                                    Fabricante Nome da Marca  \
# Nome do Produto
# Contoso Wireless Laser Mouse E50 Grey            Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Grey    Contoso, Ltd       Contoso
# Contoso Optical Wheel OEM PS/2 Mouse E60 Black   Contoso, Ltd       Contoso
# ...

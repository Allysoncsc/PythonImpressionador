# %%
import pandas as pd

#asa vezes daa erro na importaação
#colocaar no final ecoding='ISO-8859-1'

vendas_df = pd.read_csv(r'Tratamento de Dados e Multiplas Bases\Contoso - Vendas - 2017.csv',sep=";")
produtos_df = pd.read_csv(r'Tratamento de Dados e Multiplas Bases\Contoso - Cadastro Produtos.csv',sep=';',encoding='ISO-8859-1')
lojas_df = pd.read_csv(r'Tratamento de Dados e Multiplas Bases\Contoso - Lojas.csv',sep=';',encoding='ISO-8859-1')
clientes_df = pd.read_csv(r'Tratamento de Dados e Multiplas Bases\Contoso - Clientes.csv',sep=';',encoding='ISO-8859-1')

#display(vendas_df)
#display(produtos_df)
#display(lojas_df)
#display(clientes_df)


#exluido colunas;   axis = 0 -> linhaas  axis = 1 -> colunas
#clientes_df = clientes_df.drop(['Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10'],axis=1)


clientes_df = clientes_df.rename(columns={'ÿID Cliente':'ID Cliente'})
produtos_df = produtos_df.rename(columns={'ÿNome do Produto': 'Nome do Produto'})
lojas_df = lojas_df.rename(columns={'ÿID Loja':'ID Loja'})

clientes_df = clientes_df[['ID Cliente','E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja','Nome da Loja']]



# display(clientes_df)
# display(produtos_df)
# display(lojas_df)



#usando merge para juntar colunas
# dintaxe         =           datframe          coluna em comum
# novo_dataframe = dataframe1.merge(dataframe2,on='coluna)
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df,on='ID Cliente')
vendas_df = vendas_df.rename(columns={'E-mail':'E-mail do Cliente'})

#display(vendas_df.head())

# %%
#exportando para csv
#vendas_df.to_csv('Nova_Vendas.csv',sep=';')
vendas_df = vendas_df[:30]
vendas_df = vendas_df.sort_values('Quantidade Vendida',ascending = False)


vendas_lojas = vendas_df.groupby('Nome da Loja').sum()
vendas_lojas = vendas_lojas[['Quantidade Vendida']]

vendas_lojas = vendas_lojas.sort_values('Quantidade Vendida')

display(vendas_df)
vendas_df.to_csv('Novas_Vendas.csv',sep=';',encoding='latin1')
# Out:
#     Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 3             18610    08/01/2017    10/01/2017         2      200
# 12           811927    29/10/2017    31/10/2017         2      100
# 21           169169    11/03/2017    14/03/2017         3       22
# 25           793013    23/10/2017    27/10/2017         4      310
# 19           383897    25/05/2017    28/05/2017         3      306
# 23           882052    24/11/2017    29/11/2017         5       59
# 6            873068    21/11/2017    22/11/2017         1      275
# 10           860046    16/11/2017    16/11/2017         0      191
# 29           705272    24/09/2017    24/09/2017         0      200
# 15           638297    27/08/2017    27/08/2017         0      262
# 11           415344    04/06/2017    05/06/2017         1      231
# 4            287704    23/04/2017    26/04/2017         3       76
# 9            413808    04/06/2017    06/06/2017         2      185
# 16           372597    21/05/2017    22/05/2017         1       86
# 22           333103    09/05/2017    09/05/2017         0      199
# 28           448950    15/06/2017    15/06/2017         0       78
# 0                 1    01/01/2017    02/01/2017         1       86
# 2            191019    20/03/2017    21/03/2017         1      172
# 20           645873    31/08/2017    31/08/2017         0      309
# 7             26350    12/01/2017    18/01/2017         6       21
# 14           836335    07/11/2017    08/11/2017         1      237
# 18           786402    21/10/2017    25/10/2017         4      306
# 1            880458    23/11/2017    23/11/2017         0      306
# 27           491564    29/06/2017    03/07/2017         4      307
# 13           364459    19/05/2017    20/05/2017         1       26
# 24           669111    09/09/2017    09/09/2017         0      310
# 5            373600    22/05/2017    29/05/2017         7       33
# 26           177580    14/03/2017    23/03/2017         9       84
# 17           614980    18/08/2017    18/08/2017         0      306
# 8            180875    16/03/2017    16/03/2017         0      268
#
#     ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 3          448            2        6825                  48
# 12         431            1        6825                  30
# 21         437            2       21344                  27
# 25        1637            1       21344                  20
# 19         347            1       21344                  20
# 23        1607            4       21344                  13
# 6          246            5        6825                  13
# 10         578            4        6825                  13
# 29         716            3       21344                  12
# 15         356            1        6825                  10
# 11         997            1        6825                  10
# 4          280            1        6825                  10
# 9         1197            1        6825                  10
# 16         981            1       21344                  10
# 22         591            1       21344                  10
# 28         340            1       21344                  10
# 0          981            2        6825                   9
# 2          376            2        6825                   9
# 20         968            9       21344                   9
# 7          568            2        6825                   9
# 14         322           10        6825                   8
# 18         226           10       21344                   8
# 1          235           10        6825                   8
# 27        1639            7       21344                   6
# 13         845            1        6825                   5
# 24         777            1       21344                   5
# 5         1284            1        6825                   5
# 26           6            2       21344                   4
# 17        1621            9       21344                   4
# 8          975            6        6825                   4
#
#     Quantidade Devolvida                                    Nome do Produto  \
# 3                      0                     WWI Desktop PC1.80 E1801 Black
# 12                     0         Adventure Works Desktop PC1.80 ED180 Brown
# 21                     0         Adventure Works Desktop PC1.80 ED182 White
# 25                     0          Contoso DVD 48 DVD Storage Binder M50 Red
# 19                     0                    Fabrikam Laptop14.1 M4100 White
# 23                     0         SV DVD 12-Inch Player Portable M400 Silver
# 6                      1  Contoso Home Theater System 4.1 Channel M1410 ...
# 10                     0                  Contoso Projector 720p M621 Black
# 29                     0             Proseware High Speed Laser M2000 White
# 15                     0                     Fabrikam Laptop14.1W M4180 Red
# 11                     0       A. Datum SLR-like Digital Camera M400 Silver
# 4                      0  Contoso Home Theater System 2.1 Channel M1210 ...
# 9                      0     Fabrikam Budget Moviemaker 1/2'' 3mm E300 Grey
# 16                     0         A. Datum Advanced Digital Camera M300 Pink
# 22                     1                  Contoso Projector 480p M480 White
# 28                     0                      Fabrikam Laptop17 M7000 Black
# 0                      1         A. Datum Advanced Digital Camera M300 Pink
# 2                      0              Adventure Works Laptop12 M1201 Silver
# 20                     1           A. Datum Bridge Digital Camera M300 Grey
# 7                      0              Proseware Projector 480p DLP12 Silver
# 14                     0                     SV Car Video LCD7 M7002 Silver
# 18                     0  Litware Home Theater System 2.1 Channel E210 B...
# 1                      0  Litware Home Theater System 7.1 Channel M710 B...
# 27                     0          Contoso DVD 38 DVD Storage Binder E25 Red
# 13                     0             Contoso Bright Light battery E20 White
# 24                     0          Contoso Reserve Pen -Tablet Pen E200 Blue
# 5                      0        Contoso Mini Battery Charger Kit E320 Black
# 26                     0                   Contoso 2G MP3 Player E200 Black
# 17                     0                     Contoso DVD Movies E100 Yellow
# 8                      0    A. Datum Ultra Compact Digital Camera M190 Pink
#
#                           Nome da Loja             E-mail do Cliente
# 3                Loja Contoso Catalog         rbrumfieldmy@ameblo.jp
# 12                 Loja Contoso Plano         rbrumfieldmy@ameblo.jp
# 21           Loja Contoso Westminster   makayla3@adventure-works.com
# 25          Loja Contoso Asia Reseller  makayla3@adventure-works.com
# 19         Loja Contoso Europe Online   makayla3@adventure-works.com
# 23             Loja Contoso Manitowoc   makayla3@adventure-works.com
# 6                  Loja Contoso Busan         rbrumfieldmy@ameblo.jp
# 10             Loja Contoso Annapolis         rbrumfieldmy@ameblo.jp
# 29               Loja Contoso Catalog   makayla3@adventure-works.com
# 15          Loja Contoso Bangkok No.1         rbrumfieldmy@ameblo.jp
# 11               Loja Contoso Hofheim         rbrumfieldmy@ameblo.jp
# 4          Loja Contoso Beaumont No.1         rbrumfieldmy@ameblo.jp
# 9                Loja Contoso Roanoke         rbrumfieldmy@ameblo.jp
# 16                Loja Contoso Austin   makayla3@adventure-works.com
# 22  Loja Contoso North America Online   makayla3@adventure-works.com
# 28         Loja Contoso Beaumont No.2   makayla3@adventure-works.com
# 0                 Loja Contoso Austin         rbrumfieldmy@ameblo.jp
# 2               Loja Contoso Hartford         rbrumfieldmy@ameblo.jp
# 20        Loja Contoso Europe Reseller  makayla3@adventure-works.com
# 7            Loja Contoso Wheat Ridge         rbrumfieldmy@ameblo.jp
# 14           Loja Contoso Giebelstadt         rbrumfieldmy@ameblo.jp
# 18         Loja Contoso Europe Online   makayla3@adventure-works.com
# 1          Loja Contoso Europe Online         rbrumfieldmy@ameblo.jp
# 27           Loja Contoso Asia Online   makayla3@adventure-works.com
# 13              Loja Contoso Loveland         rbrumfieldmy@ameblo.jp
# 24          Loja Contoso Asia Reseller  makayla3@adventure-works.com
# 5               Loja Contoso Berthoud         rbrumfieldmy@ameblo.jp
# 26                Loja Contoso Humble   makayla3@adventure-works.com
# 17         Loja Contoso Europe Online   makayla3@adventure-works.com
# 8             Loja Contoso Tokyo No.2         rbrumfieldmy@ameblo.jp
